# %% [markdown]
# # WEB SCRAPING IMAGES FROM GOOGLE
#
# Came across two methods:
# 1. Using Beautiful Soup
# 2. Using Selenium
#
# Got stuck on Beautiful Soup so had to switch to Selenium. I found Selenium a bit more complex than Beautiful Soup, but I think it's visual output feature makes it a fascinating tool.
#
# The Selenium package does what a human user would normally do on the web browser. In this case I want to go to Google Images and search for images of Dogs and store it on my desktop, Selenium would automate the process for us by specifying which image you want to download and how many images you want to download.

# %% [markdown]
# ### Importing libraries

# %%
import selenium
from selenium import webdriver
import time
import os
import requests
from PIL import Image
from PIL.ExifTags import TAGS
import io
import hashlib
import pandas as pd
from openpyxl import load_workbook

# %% [markdown]
# ### Chrome Driver Path
#
# To use Selenium with Google Chrome we need to download a Chrome Driver, depending on the Google Chrome Version the Chrome Driver is installed.

# %%
DRIVER_PATH =  '/Users/apurvasalvi/Desktop/GauguinBot/chromedriver'
wd = webdriver.Chrome(executable_path=DRIVER_PATH)
wd.get('https://google.com') 
#search_box = wd.find_element_by_css_selector('input.gLFyf') #input box selector
wd.quit()

# %% [markdown]
# The above lines of code only opens the browser and gives the input query and quits.
#
# The second phase would involve to search for the query, go to the image section and get the respective image links using css selectors.
#
# The third phase of the code will be to download the images from the link onto your local computer.

# %% [markdown]
# ### Code for Web Scraping from Google Images

# %%
def fetch_image_urls(plot:str, max_links_to_fetch:int, wd:webdriver):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
    # build the google plot
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
    
    wd.get(search_url.format(q=plot))
    
    image_urls = set() #duplicates won't be added
    image_count = 0
    results_start = 0
    image_tags = set()
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)
        
        #find elements based on the tag and class name using css selector
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd") 
        number_links = len(thumbnail_results)
        print(f"Found: {number_links} search results. Extracting links from {results_start}:{number_links}")
        
        for img in thumbnail_results[results_start:number_links]:
            #try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(1)
            except Exception:
                continue
            
            #extract image urls    
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))
                    if actual_image.get_attribute('alt'):
                        image_tags.add(actual_image.get_attribute('alt'))
                    else:
                        image_tags.add("Image Tag not found")
                        
            image_count = len(image_urls)
            
            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(10)
            show_more_results = wd.find_element_by_css_selector(".mye4qd")
            if show_more_results:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)
    
    return image_urls, image_tags

def download_image(folder_path:str,file_name:str,url:str):
    try:
        image_content = requests.get(url).content
    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")
        
    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')  #Opens and identifies the given image file
        folder_path = os.path.join(folder_path,file_name) #Joins 2 or more pathname components
        if os.path.exists(folder_path):
            #if the path exists, add file to the folder path
            file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
            image_id = hashlib.sha1(image_content).hexdigest()[:10]
        else:
            #else create a new folder and add file to the new folder
            os.mkdir(folder_path)
            file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
        with open(file_path, 'wb') as f:  #'wb': mode for binary random access, opens and truncates the file to 0 bytes
            image.save(f, "JPEG", quality=85)  
        print(f"SUCCESS - saved {url} - as {file_path}")
        if image_id is not None:
            return image_id
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

if __name__ == '__main__':
    wd = webdriver.Chrome(executable_path=DRIVER_PATH)  #controls chrome driver and allows you to drive the browser
    plot_names = ["Nightingale Rose Chart"]  #list of search keywords
    for plot in plot_names:
        wd.get('https://google.com')   #loads webpage in the current browser session
        search_box = wd.find_element_by_css_selector('input.gLFyf')   #finds an element by css selector and returns it if found
        search_box.send_keys(plot)   #simulates typing into the element
        links, tags = fetch_image_urls(plot,500,wd)  #gets image urls
        images_path = '/Users/apurvasalvi/Desktop/GauguinBot/images' #folder to save the element
        metadata = pd.DataFrame(columns=["Image ID", "Image Source", "Image Tag", "Image Format", "Image Mode", "Image Size", "Image Palette"])
        for i,j in zip(links, tags):
            image_id = download_image(images_path,plot,i)   #downloads images to the specified pathNone:
            if image_id is not None:
                file_path = str(images_path) + "/" + str(plot) + "/" + str(image_id) + ".jpg"
                image = Image.open(file_path)
            else: 
                continue
            data = {"Image ID": image_id, "Image Source": i, "Image Tag": j, "Image Format": image.format, "Image Mode": image.mode, "Image Size": image.size, "Image Palette": image.palette}
            metadata = metadata.append(data, ignore_index=True) 
        out_path = "/Users/apurvasalvi/Desktop/GauguinBot/Metadata.xlsx"
        writer = pd.ExcelWriter(out_path , engine='openpyxl', mode='a')
        metadata.to_excel(writer, sheet_name=plot)
        writer.save()
        writer.close()
    wd.quit()
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 167 image links, looking for more ...
# Found: 312 search results. Extracting links from 100:312
# Found: 500 image links, done!
# SUCCESS - saved https://d2mvzyuse3lwjc.cloudfront.net/images/WikiWeb/Graphing/Graphing_SmithChart.png?v=11016 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/971e33425b.jpg
# ERROR - Could not save https://d2mvzyuse3lwjc.cloudfront.net/images/WikiWeb/Graphing/Graphing_SmithChart.png?v=11016 - local variable 'image_id' referenced before assignment
# SUCCESS - saved https://miro.medium.com/fit/c/160/160/1*l5ScCuzT0SKFbZ8ko5skDg@2x.jpeg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8b32a87f83.jpg
# SUCCESS - saved https://www.page45.com/world/wp-content/uploads/2014/08/Corpse-Talk-Florence-Nightingale.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/97a1c065fd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSiYBp5mqhYDFc1hiR-N4ppF0p2Hn9jTuapDA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/588863be58.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSttBHc1wW853_RJIX3dWeqoHrs1BjS8ooXWA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/effeff272c.jpg
# SUCCESS - saved https://www.mdpi.com/applsci/applsci-10-02182/article_deploy/html/images/applsci-10-02182-g012.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/70ae6a686b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSpE_wn0yk5wDPxEyK1_nrO0rb-iBanvkBYeQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8a2d7aba0b.jpg
# SUCCESS - saved https://gw.alipayobjects.com/mdn/rms_f5c722/afts/img/A*hRsjRooYy2QAAAAAAAAAAABkARQnAQ - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7ae53871ed.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ895uKw03tgTSzn4F3XlFV5rfp-6l87PjDvw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a70213ac99.jpg
# ERROR - Could not save https://datavizproject.com/wp-content/uploads/2016/06/DVP_1_100-40.png - cannot identify image file <_io.BytesIO object at 0x143a54308>
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRI1lQSO5gqVCIxS7VJwe1AaiSyOAKpYN87FQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3f567e4310.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQSBwr2L1ZH88UF5GzJhwS1UlOxd-XIUagofg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/509a5259cc.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR_0EinLGdrNiwzECbJ8tlS4N01QoOUgHvfOQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/cf1c76dad9.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSdAoCyRsa7tB9GlpzOMG7DtjiwylhXBU_fMw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/05a78ad456.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRmYZUM3cR0pZCuY2sXXIl3udOi1edMGAO1KQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/502db9786f.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRWsgmJFRCeq2KLU_wYdp6YESIRtsyLXlVBfw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/40a453f923.jpg
# SUCCESS - saved https://junkcharts.typepad.com/.a/6a00d8341e992c53ef01b8d25dbb39970c-pi - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c4555af42e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRfJqqcYiiETQD5-nRjNqwevsPBAu7WYKRfhQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6d884464a0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQEmXg1eziPjzonAr_M-eHl2ZLZpzSwsMI2Rw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6e617fd5e0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTeLx-J5vVVqnEDgKXC7iXNArQnx39hgbnsWA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b7fafeb14e.jpg
# SUCCESS - saved https://image.slidesharecdn.com/slideshare-121114031408-phpapp02/95/open-source-web-charts-13-638.jpg?cb=1352937594 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/22ae15ffb5.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTgiCs1OHhM_IjccoKSXcttOGQ_lKbCDcHKPw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b68bcb91f6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSi6OvFk6Z6lvNOKP0XdRbUyabiBx67PBEPwQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3e31f13688.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQybiqAcx5OR4WXqre9bwHyCiuUck3RDg3GSw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3c3e756a68.jpg
# SUCCESS - saved https://gw.alipayobjects.com/mdn/rms_f5c722/afts/img/A*o3i0R5ODPzMAAAAAAAAAAABkARQnAQ - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/511548f91c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQAWIR3VGkImTifX_skGAB9M5CdYhCVfBZcig&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2d40f5f561.jpg
# SUCCESS - saved https://i.guim.co.uk/img/static/sys-images/Guardian/Pix/maps_and_graphs/2010/8/12/1281630258137/Nightingale-graphic-006.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=61cb475b1748e4efa3414d18a27a5745 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/fc83a57324.jpg
# SUCCESS - saved https://static.observableusercontent.com/thumbnail/16a7c7de63107572c1c240b30dac1c17f33f4a8702d885c9f3d26ba6c4962d36.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a2939e93cf.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSJpxpqg5LZ4640kTNsebTzPjSO9s8AChTaTg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7badb79ba0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTYeZ7vMFUGc4SRHWFzsDJSsFpudw3MhTkVuw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3d064a0515.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTzsBouw9gUmzToeGeKclGbtODA2ERSUyJNLw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/908734c0ee.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRgzfunQYgm2wztn3nBXSAANAF4ZN3RNXaLgw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6c3f85601c.jpg
# SUCCESS - saved https://i0.wp.com/sticksandticks.com/wp-content/uploads/2016/05/nightingale.png?resize=676%2C345 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/57902d0501.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSw_2QJVjvQNnkzpjYG3M0ZoGKsaIWAj1mjuA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1966bcbaf5.jpg
# SUCCESS - saved https://i.ytimg.com/vi/oMuwtGMtzRA/maxresdefault.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/afde9f52cc.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSm7_XZckoPgMC53-cyDQ7RERHqbfT4f6GGqA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6f274a6799.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRSYGGqOcv3b90wNSrt_ww2PrQmCb8N_Hha0g&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1017c2d436.jpg
# SUCCESS - saved https://user-images.githubusercontent.com/111269/39058444-adae79e0-4470-11e8-958c-3f4fb97d7e42.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/09859a3abc.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRRf_jxIRjKqAWoj7v6Yze6eHO0lIEJOeHu_w&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6f94751167.jpg
# SUCCESS - saved https://nightingalebenefits.com/wp-content/uploads/2020/03/Nightingale-Benefits-member-savings-chart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/e0cabf612c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSZVcHWohft-KafFCV0jRs2boH-z3_CxaI0Lw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3ab0b3d38d.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Piechart.svg/300px-Piechart.svg.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/66ca0a037d.jpg
# SUCCESS - saved https://www.amcharts.com/wp-content/uploads/2018/11/demo_12356_none.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/283e5b2a2d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS3KHbPJz4y3PD5hsCaItgCy0ht-xzPx5R_QQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5617b86e87.jpg
# SUCCESS - saved https://www.jeppt.com/uploads/thumbnails/nightingale-rose-chart-ppt-chart-download.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f236eb8fa8.jpg
# SUCCESS - saved https://preview.anychart.com/pg/g9zpzefs-7.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/ef99dd746c.jpg
# SUCCESS - saved https://gw.alipayobjects.com/mdn/rms_f5c722/afts/img/A*377_TZgcotkAAAAAAAAAAABkARQnAQ - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/82df67ff45.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRZE6nJ80n2Nz-g9Cex-z6ZHX91fdjqCSxHDA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b5707bcd87.jpg
# SUCCESS - saved https://www.edwardtufte.com/bboard/images/00013h-831.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/76360f9aba.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTPtm4-fx3fUKlShgKk3k9Tx5IiXun7oIOjnA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6564ebd146.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTOrPQt9xtY-CsxlGDDAbTPV3RJC35y4RZcyA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/916bd087e0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRQyHdvSOc0T8Btl7NxPyss5W5QPvLi4jm5cQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/fae0a10617.jpg
# SUCCESS - saved https://cdn.theathletic.com/app/uploads/2019/04/27001807/Irv-Smith-Polar-Rose-Chart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f2625f016d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ1mxQgssbRVTPAjctFUWfFjT6RumPb5465gQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8e07e69716.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSP5nYz_5alxPMYEXS52OTnERnAhu4KGU0qTg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7d4bcc4300.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT2mI8rduNG9qDRu5RdZu8Qqgw1Z-fcR9MmWg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a9909c42cb.jpg
# SUCCESS - saved https://i.imgur.com/gs90W3r.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/86c5f366e5.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT4HBRPpAo3NgXL8t5ElwqCJ0ZwTKqcq30Ikg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/24fbb7eebd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQDAApXTJ8m9hCMLk8cWNjKFOm9HvbQ98PntQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8708949462.jpg
# SUCCESS - saved https://hernanresnizky.files.wordpress.com/2012/12/nightingale-1.png?w=500&h=289 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/fbd7d7aaaf.jpg
# SUCCESS - saved https://miro.medium.com/max/3412/1*VP0j5hGmTIA0XpPv1_NRsg.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a1b8d5b867.jpg
# SUCCESS - saved https://lh6.googleusercontent.com/-MjfwK-X_V04/UfqlM6-Zk8I/AAAAAAAAAiA/iW1MGvZwY_g/w625-h500-no/Dotplots3.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f4b263bc3e.jpg
# SUCCESS - saved https://d2mvzyuse3lwjc.cloudfront.net/images/WikiWeb/Graphing/RadialBarChart.png?v=12178 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/44b6454e24.jpg
# SUCCESS - saved https://flowingdata.com/wp-content/uploads/2009/11/pie.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/4a13ec4a29.jpg
# SUCCESS - saved https://preview.anychart.com/pg/udddzst2.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0eb3d0ef15.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRPzbv3x6ayDUOxZ_0b0SHzm9Bg1ouZwZw_CQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b8f0fe6293.jpg
# SUCCESS - saved https://programmersought.com/images/377/589c5a07aa92b56b9147db17a4bc15c9.JPEG - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/4dc5645996.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTh4OcqRmRj7dMaa8ly7XUB_j3M-rcBVfejoQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/84efa51809.jpg
# SUCCESS - saved https://www.homeppt.com/uploads/data/21352/9VRPZSW4bBEuwhkn.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/9e6b9bd59d.jpg
# SUCCESS - saved https://3.bp.blogspot.com/--aZgVR4uZF4/V3PsWiI8ihI/AAAAAAAAXpM/Ti9JRevcga4G1ZRXeyubT86D9KN7JTRVQCLcB/w1200-h630-p-k-no-nu/col_clive_1855_florence_nightingale_rose_chart.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f5275ff869.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSaGEnkY2ybDYi_52IfwmL1kQ-awNYpn0WQjg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/595c8619e2.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRc9-tW08gS-G7LpMOQv9AL07mNNLXUDZ4gZw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/33a0f2696b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRkQFQh0JqZDyqi8En3V7ziXdJvC7wEXV5Dcg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5bd14ebab1.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQjDMNr9W44tvqXvMCymoGscGlPqtHRc6uleQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/d376d46e2d.jpg
# SUCCESS - saved https://images.squarespace-cdn.com/content/v1/5b872f96aa49a1a1da364999/1581409564909-7E320FEMCWHF3D5G92JF/ke17ZwdGBToddI8pDm48kDogYgQdVQAkUW98gmY9Vgt7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z4YTzHvnKhyp6Da-NYroOW3ZGjoBKy3azqku80C789l0lCvyAd1-5UQFnp8aARaJsX8L94t2u-XxysXjqpmT3livZa5xrrf04fAJQc50Z6gVg/IMG_3569.JPG - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2685ba48ba.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTaoFqC7kVbTCeLSr0UCWVx1HW5zKjUwI8njg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f8fbf0a789.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRYcK4UYPgwoyK21nfAyARHDsW1_8jiM_-EZQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b8abf59611.jpg
# SUCCESS - saved https://echarts.apache.org/examples/data/thumb/scatter-effect.jpg?_v_=20200710_1 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f9879f9927.jpg
# SUCCESS - saved https://i.ytimg.com/vi/dpMYmpjY65c/maxresdefault.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7a0d33940f.jpg
# SUCCESS - saved https://vizzlo.com/img/vizzards/examples/nightingales-rose-chart/the-expanding-demand-for-coding-skills-400x.png? - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/07a60fe7c4.jpg
# SUCCESS - saved https://image.slidesharecdn.com/slideshare-121114031408-phpapp02/95/open-source-web-charts-19-638.jpg?cb=1352937594 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/9835372095.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQHX_OB31e0gVqeBsTMT60__vHI1bv01SxK7Q&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b24ca93993.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQteBWssqTzL9x0-abi7eB7mU3v0zNCpXb8Lw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8fa9c454a6.jpg
# SUCCESS - saved https://uploads-ssl.webflow.com/5dc27bf865f41cedb4b7b9a5/5ec13c8b7b4d114444f12d5c_FWc9t4IYxTiwQNvi-XkDCGQpfNHIzCkUDezCBxszD_BAgJ5h41OtBEqvNcRR5UNJYYrJ8PaAA_NZcKrYb3AtmHWu2F_3brX2BW1wbe7iz9MCBGUz1gNybwdjuB1tVpIvZ0M9eScz.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/27bf94c370.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR3zD2fi3ywXv_eVf4Ff050yVohEUijlR1RkQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f213a0514f.jpg
# SUCCESS - saved https://www.finereport.com/en/wp-content/uploads/2020/03/worldrosechart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/d7982bc000.jpg
# SUCCESS - saved https://datavizcatalogue.com/images/buttons/PNG/on/pie_chart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/cd0a5bec16.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSOcxFYCUqqWbCfA_WpSHYc06RPKKTM3EDMhA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/29875a0a15.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTMa9iJGfZoWIgiJ9A_CAyhJpPwkhzt3Zum-Q&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c26a8b00e6.jpg
# SUCCESS - saved https://www.researchgate.net/publication/324119458/figure/fig4/AS:610062695428096@1522461689868/Nightingale-Rose-Diagrams-NRDs-of-the-upper-U-middle-M-and-lower-L-river.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c308a93991.jpg
# SUCCESS - saved https://images.plot.ly/plotly-documentation/thumbnail/wind-rose.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8ade244017.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/1/17/Nightingale-mortality.jpg/800px-Nightingale-mortality.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/68e806f25d.jpg
# SUCCESS - saved https://i0.wp.com/tableaumagic.com/wp-content/uploads/2019/10/coxcomb-00.png?fit=600%2C400&ssl=1 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/fa04307f03.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSNS1_mFjd4ng61S7QLLPfdSNMYgaN2a2YeCQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/ca352af669.jpg
# SUCCESS - saved https://miro.medium.com/max/2250/1*rvDrQijb3X2pm0Hrc4mkjA.jpeg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/afa5650150.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTTdVH0Xhc_8D-OnYYZFHlv98pY4rpfQGpD9Q&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/e76e4eca2c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTVjL5SP4QEQn6hFJCo4MQcJWWjBhvICFSXRg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/9ab5e00cfe.jpg
# SUCCESS - saved https://lh3.googleusercontent.com/proxy/AR0IBAkUN5nhayaJHcB8dUuD2imWGiqOn1vzPwmwtR7Nh5n5tyCudNCgb6O8wM9rMwEsBptAzsaXFw68_WiOTDvzLJ2cyfJ8-Wx-GlCgX-2Q1P2iHAFfPAVVXnhBbOISzdVElTpvbIQL5SLeyXjKK_plgnSqpBB2uTPkEHIFicvhRG7B9av6Y1NfHk-e7SRZj3nMYzqOLFoizqMTU1SW - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/248ac3bb85.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTtppQOPJLmS420JDPPIb-UROjgeXVhuGYUvA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/48a8a41f8b.jpg
# SUCCESS - saved https://public.tableau.com/static/images/My/MyRosechart/MyRosechart/4_3_hd.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5d2f1fbf1f.jpg
# ERROR - Could not save https://datavizcatalogue.com/methods/images/anatomy/SVG/nightingale_rose_chart.svg - cannot identify image file <_io.BytesIO object at 0x116e1a780>
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQXARKl7OuUNHcKAHP0AgYLlvSMh51WJ5M85w&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b307ed2d75.jpg
# SUCCESS - saved https://i.ytimg.com/vi/ICFNS0ta1o4/maxresdefault.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/9ed43dfd98.jpg
# SUCCESS - saved https://understandinguncertainty.org/files/3SegmentBarChart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/694b24316b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRxzUnzCgl-FYiZyEK5V6Pw4AVgdcrJcDwP_g&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7f38b0cad7.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQQoXsXDF1pJ2FYK1MMlbp4QEb6GRliIKusAQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c7ce0860b4.jpg
# SUCCESS - saved https://www.finereport.com/en/wp-content/uploads/2020/03/03.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a931ed0946.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSf4xJ__GuP_Afcfwpn0w0miax4GOU7eda84A&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f17230768a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTnOfYLisI5CY_n2puWoSWjeVdmCI27yNC9VQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/d4500a31a2.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQuPn7at-veNvR1hNKLGPZY11adp31-p0Apeg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/247d403b01.jpg
# SUCCESS - saved https://dataforvisualization.com/wp-content/uploads/2020/02/nightingale-rose-chart-1024x683.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0fb2bfcf66.jpg
# SUCCESS - saved https://understandinguncertainty.org/files/3SegmentCoxcomb.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/bd7def51c3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcToVDKYs8AvmL2gFU73FLf3mlu3LxwKRIZVbw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/fc816537e9.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT8kVvAHrdZJSCxxF_aX7gkv1wbVPWf85zuwQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2fafd0c6aa.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSkWMLRPeklvUSLjF8wtzIVIb62qZi4ixhuLQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/24f53ef78c.jpg
# SUCCESS - saved https://cdn.dribbble.com/users/44850/screenshots/4066943/zulu5nightingale_1x.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/35e62d9b9b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQru8Kzrn6mgPvqEYKBiNejx-lU0AfNF-8pbA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2d910904ae.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ_nQtbpIFWqw-v0mAOn8wgobHD8Kj49dhYmw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/8dfceee14d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRZkJmLTRLJ1u9BuJmbx_yAh4_3F1MBDTSOzg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b6e6415bb2.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQNnL-bSiYLvD8Dk_ekyKRf_KyR088ekxsI1A&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/21973b807e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ_B2LOdZQQP3I1M_QTM3C03WehUKPkLWUXjg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0de36728e7.jpg
# SUCCESS - saved https://online.visual-paradigm.com/repository/images/b5e5eb25-1eba-4908-8e10-111f1f824dd4.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/9a658eab36.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRVIfrBmTqP33eQS9LQHxEIMoGUIPhuWN0njA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/29eb6e7ae8.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Doughnut_shape_Pie_Chart.jpg/220px-Doughnut_shape_Pie_Chart.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/4a72bbc28a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRP9LtJJqNCOw0kJC6G_ObY_Xt3B9cV70wZOA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/67b82ab8f2.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTTBw65RKLFixwUY66MC_jIjrLtT6VvWbDd0g&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/59f7bfdfa8.jpg
# SUCCESS - saved https://lh3.googleusercontent.com/proxy/NVRATwu8LdFOAOduneK2etPXk1E5KI5K6FbZi1XuRLRt2pCtJW3ZfN_zxPPRpONPkuqNLtjriFtweyjam0rM-ihitbIW1RuO-6OjMrBC27oy3KoK_9i9xYnU4rK-4Emxy0zxwAyd3PkKFTlTmDf0oYoWFj6iiwfeGfQa2vggohw - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/dd911c7462.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSyQlHM8pVnfzwgmH3_-ZkchqbS3B2LN8O0zQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/92cc158904.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTvuw_B5Ryuv6ye6p4zQGN0RygYqGeIUN-sdQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c9f27294cd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQujEW9hEF6fJoplxIKT3uwwIxOu7ZyRcPCdA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f3460c5b42.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRolAJecvMnx7tche7uxdxFiECfMTgzmVco8A&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/3df1de7791.jpg
# SUCCESS - saved https://preview.anychart.com/pg/ngasup8c.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0224219164.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRekRTxSK4evWBFqhzJSJghhHnDmsE_KH0Prg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5dc663400c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ1NOatLG7iM3djcx-YIlDU6VnidX8OuaWV8w&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/76184ae319.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRKt-0_qaL5lKbQB9OdnhlRtNv_U3IoN71q5w&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2796abd308.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQIQnZals_R4HUXIaEVRcx4299hk8taKLLeAg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6ccfcf3016.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRNymjz3dwSNkh-R8cYW2Bs05DefnmqXt2jDw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/82cdea4958.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTam2y4Hs3ArGWLD5rLzFRBC9xATXjGqYLjaw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/50250eb27c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTKcfMSOyDl4NGPWFmrRtVgV23m1XPejy8UGQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/335480457d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTtl4kZvw1bMqWaH0EwJx1B_FWdzdDyk_r-FA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a143ee1ddc.jpg
# SUCCESS - saved https://ars.els-cdn.com/content/image/1-s2.0-S001282521930594X-gr6.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c3fe8c4d1c.jpg
# SUCCESS - saved https://lh3.googleusercontent.com/proxy/YDM-N43FoUEMgg2PzUmNMXjdRPJzORf-dPG9BWL9FlcADg_kW5xgX5Drnvnqb6jfQekS8vqB3UJEZWxf_cUXNAv2nqL9 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0d2d992c79.jpg
# SUCCESS - saved https://programming.vip/images/doc/b2d7e509a040f406143c2f38b7aa108c.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a94c1833a0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRflXcKJSIOyyBlddDadj1eJCtlOu8FlpRMsA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/f0996a595a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSA45ijIkwb-OoA_MfXYBMC2zYYxsFKwKio4A&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2651b39555.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSC1sTAMQpkJurKXyjrfQbRa2otGuwHEA06jg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1e8b0f7620.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQJPefmcolkUGoZycifrUXXqI4-uBagkB3Olg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/e8439c4423.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQWtWjdmLCayEpYe2nqUU_yiNqxpkkUPwiGKA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/a1169c46b7.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRCdme7hcAa8CfDPYwxA_IOmgYn8VnfoDGxTw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/dae9143bef.jpg
# SUCCESS - saved https://s3.amazonaws.com/libapps/accounts/69232/images/Typres_Radar.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7c9480d60f.jpg
# SUCCESS - saved https://raw.githubusercontent.com/AAChartModel/Gallery/master/AAChartKit/seriesZonesChart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b90ba70ae4.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQfv2qi9y-cUniFBz3zmDHj6RgczWFGO9SKjg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/b134f9b0c4.jpg
# SUCCESS - saved https://i1.wp.com/tableaumagic.com/wp-content/uploads/2020/05/Coxcomb.png?fit=1280%2C720&ssl=1 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/aa212d2f5c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT8T3G5oj7nbQB57i2ELr2Lsxaffm__-jEvxg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5eadfd8a83.jpg
# SUCCESS - saved https://public.tableau.com/static/images/Ni/NightingalesRose_5/Sheet1/1_rss.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2836d37bbf.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTXDHOoeBORouIlw5rBTEdxCKYabpVIUFUdog&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/40e3a511b5.jpg
# SUCCESS - saved https://miro.medium.com/max/4052/1*5JLbj_e9kuJ5gAmnYuvU8g.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/eee436dd08.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTzOK8TJexoZmjL_qYAsh8UcvbF9Z83PA3-vg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/18cbf07df3.jpg
# SUCCESS - saved https://i.stack.imgur.com/u6LzY.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0e8ea6b13c.jpg
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/9/9e/Nightingale_Rose_Chart.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/413cb11ae0.jpg
# SUCCESS - saved https://www.finereport.com/en/wp-content/uploads/2020/03/01.gif - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/19160e1fb6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQEDvDJYuvLuDRwNhQY-Z0_oF6wHgxcBrdyRw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1b5d6d4949.jpg
# SUCCESS - saved https://sites.google.com/site/distantyetneversoclose/_/rsrc/1326438595627/excel-charts/florence-nightingale-circumplex-chart/Flo%20Nightingle%20Circumplex%20Chart.png?height=237&width=400 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/377587d422.jpg
# SUCCESS - saved https://www.thedataschool.co.uk/wp-content/uploads/2017/01/pathid-points.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/c41c681c19.jpg
# SUCCESS - saved https://preview.anychart.com/pg/l2lnp24g.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/d860a885a7.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSApiV95L7NKpD7LEOwDyER_y9VSS67Nyshkw&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0a8d7484f3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQBLKZ_jFWhmFTtO8T372q_w8tYvMPV43Wh7Q&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/153d39c2d9.jpg
# SUCCESS - saved https://camo.githubusercontent. - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/893ec814fe.jpg
# SUCCESS - saved https://static-3.bitchute.com/live/cover_images/a4exh1mPHKBS/LGi9hf4Rzjzt_320x180.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0c9f7ea881.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS7kgGX4_dwg2ttZcw8Gvc7qL4J9XqB9tGuvg&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/6d6eac02a3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcROUQH2XSyOCmcrqqV4wufjDR61es9zzDB8Ow&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/7ae3de4b02.jpg
# SUCCESS - saved https://www.uh.edu/engines/coxcombchart.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/0cb3ef50bd.jpg
# SUCCESS - saved https://user-images.githubusercontent.com/1846999/37548453-f09ad92c-296f-11e8-96e1-2c695ef13970.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/d1cef17744.jpg
# ERROR - Could not save https://edspace.american.edu/visualwar/wp-content/uploads/sites/1168/2018/04/Screen-Shot-2018-04-23-at-6.16.08-PM-1030x865.png - cannot identify image file <_io.BytesIO object at 0x143a544c0>
# SUCCESS - saved https://datavizcatalogue.com/store/wp-content/uploads/2015/10/network_diagram.png - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/e5d09d4814.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT-o85qRU6mXQIiGkqZN2at2rzbeXjp3H90EA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1444d8174f.jpg
# SUCCESS - saved https://junkcharts.typepad.com/.a/6a00d8341e992c53ef01b7c9531dc1970b-pi - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/1b468b3c28.jpg
# SUCCESS - saved https://i.vimeocdn.com/video/725510951.jpg?mw=1920&mh=1080&q=70 - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/61ce46327e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRQymX55ePHpxg0cdbNMKq3ff7GrBVLpwQfCQ&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/4aa636b032.jpg
# SUCCESS - saved https://i.ytimg.com/vi/qwTEZlaTedM/hqdefault.jpg - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/5fcd0f33c2.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQqUWGusbNPqo_fCAw-S3cxRrpjGZ1YnbCzuA&usqp=CAU - as /Users/apurvasalvi/Desktop/GauguinBot/images/Nightingale Rose Chart/2fd2a315de.jpg

# %%
metadata
# Out:
#      Image ID                                       Image Source  \
# 0  5567760fa9  https://i.pinimg.com/originals/ef/97/b5/ef97b5...
# 1  22ede0538d  https://miro.medium.com/max/3354/1*UIL5MxvErJU...
# 2  a056d3f388  https://upload.wikimedia.org/wikipedia/commons...
# 3  c12e5def2a  https://populationeducation.org/sites/default/...
# 4  4a96a648db  https://xdgov.github.io/data-design-standards/...
#
#                                            Image Tag Image Format Image Mode  \
# 0  A Step-by-Step Guide to Making a Choropleth Ma...         JPEG        RGB
# 1  Choropleth maps: theory behind making a map on...         JPEG        RGB
# 2  Make a Covid-19 Choropleth Map in Mapbox | by ...         JPEG        RGB
# 3      Choropleth Map | Data Visualization Standards         JPEG        RGB
# 4                          Bivariate map - Wikipedia         JPEG        RGB
#
#     Image Size Image Palette
# 0   (642, 316)          None
# 1  (1677, 827)          None
# 2   (917, 633)          None
# 3   (605, 376)          None
# 4  (1200, 901)          None

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = pathlib.Path("/Users/apurvasalvi/Desktop/GauguinBot/images/Arc Diagram")

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 0

# %%
import httplib
import urlparse

def unshorten_url(url):
    parsed = urlparse.urlparse(url)
    h = httplib.HTTPConnection(parsed.netloc)
    h.request('HEAD', parsed.path)
    response = h.getresponse()
    if response.status/100 == 3 and response.getheader('Location'):
        return response.getheader('Location')
    else:
        return url
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-9f9038feaa66> in <module>
# ----> 1 import httplib
#       2 import urlparse
#       3
#       4 def unshorten_url(url):
#       5     parsed = urlparse.urlparse(url)
#
# ModuleNotFoundError: No module named 'httplib'

# %% [markdown]
# ### Contribution
#
# External Source: 70%
# Personal Contribution: 30%

# %% [markdown]
# ### Citations
#
# 1. Article title:	Web Scraping Images from Google
#
#    Website title:	Medium
#
#    URL          :	https://medium.com/@wwwanandsuresh/web-scraping-images-from-google-9084545808a2
#
#
# 2. Article title:	Msalmannasir/Google_image_scraper
#
#    Website title:	GitHub
#
#    URL          :	https://github.com/Msalmannasir/Google_image_scraper/blob/master/google_img.

# %% [markdown]
# ### Conclusion
#
# This task helped me learn how to use Selenium to web scrape any image from the internet. The task is divided into 3 steps: Opening the Web Browser using Selenium, Getting the URLs, and Downloading the images using these URLs. The above lines of codes can be used to download any number of images from the internet. Thus, I have automated the process of getting images from the web using Selenium.
